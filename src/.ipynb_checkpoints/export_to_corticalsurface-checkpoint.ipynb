# %%
import numpy as np
import nibabel as nib 
import os 
import pandas as pd
from utils.utils import * 
from utils.flips import get_prefered_xy
import math

# %%
rois_long = {'V1v': 1, 'V1d': 2, 'V2v': 3, 'V2d': 4, 'V3v': 5, 'V3d': 6, 'hV4': 7, 'VO-1': 8,
 'VO-2': 9, 'PHC-1': 10, 'PHC-2': 11, 'LO-1': 12, 'LO-2': 13, 'TO-1': 14, 'TO-2': 15
}
sior_long = {v: k for k,v in rois_long.items()}
to_reduce = {'V1v': 'V1', 'V1d': 'V1', 'V2v': 'V2', 'V2d': 'V2', 'V3v': 'V3', 'V3d': 'V3'}
sior = {v: k for k,v in rois.items()}

# %%
cos_sin = get_prefered_xy(subj_list, sessions) # save that and open it matlab 
print(cos_sin)
# Out:
# 		sub: subj01 fetching condition trials in session: 1
# 		sub: subj01 fetching condition trials in session: 2
# 		sub: subj01 fetching condition trials in session: 3
# 		sub: subj01 fetching condition trials in session: 4
# 		sub: subj01 fetching condition trials in session: 5
# 		sub: subj01 fetching condition trials in session: 6
# 		sub: subj01 fetching condition trials in session: 7
# 		sub: subj01 fetching condition trials in session: 8
# 		sub: subj01 fetching condition trials in session: 9
# 		sub: subj01 fetching condition trials in session: 10
# 		sub: subj01 fetching condition trials in session: 11
# 		sub: subj01 fetching condition trials in session: 12
# 		sub: subj01 fetching condition trials in session: 13
# 		sub: subj01 fetching condition trials in session: 14
# 		sub: subj01 fetching condition trials in session: 15
# 		sub: subj01 fetching condition trials in session: 16
# 		sub: subj01 fetching condition trials in session: 17
# 		sub: subj01 fetching condition trials in session: 18
# 		sub: subj01 fetching condition trials in session: 19
# 		sub: subj01 fetching condition trials in session: 20
# 		sub: subj01 fetching condition trials in session: 21
# 		sub: subj01 fetching condition trials in session: 22
# 		sub: subj01 fetching condition trials in session: 23
# 		sub: subj01 fetching condition trials in session: 24
# 		sub: subj01 fetching condition trials in session: 25
# 		sub: subj01 fetching condition trials in session: 26
# 		sub: subj01 fetching condition trials in session: 27
# 		sub: subj01 fetching condition trials in session: 28
# 		sub: subj01 fetching condition trials in session: 29
# 		sub: subj01 fetching condition trials in session: 30
# 		sub: subj01 fetching condition trials in session: 31
# 		sub: subj01 fetching condition trials in session: 32
# 		sub: subj01 fetching condition trials in session: 33
# 		sub: subj01 fetching condition trials in session: 34
# 		sub: subj01 fetching condition trials in session: 35
# 		sub: subj01 fetching condition trials in session: 36
# 		sub: subj01 fetching condition trials in session: 37
# 		sub: subj01 fetching condition trials in session: 38
# 		sub: subj01 fetching condition trials in session: 39
# 		sub: subj01 fetching condition trials in session: 40
# 		sub: subj02 fetching condition trials in session: 1
# 		sub: subj02 fetching condition trials in session: 2
# 		sub: subj02 fetching condition trials in session: 3
# 		sub: subj02 fetching condition trials in session: 4
# 		sub: subj02 fetching condition trials in session: 5
# 		sub: subj02 fetching condition trials in session: 6
# 		sub: subj02 fetching condition trials in session: 7
# 		sub: subj02 fetching condition trials in session: 8
# 		sub: subj02 fetching condition trials in session: 9
# 		sub: subj02 fetching condition trials in session: 10
# 		sub: subj02 fetching condition trials in session: 11
# 		sub: subj02 fetching condition trials in session: 12
# 		sub: subj02 fetching condition trials in session: 13
# 		sub: subj02 fetching condition trials in session: 14
# 		sub: subj02 fetching condition trials in session: 15
# 		sub: subj02 fetching condition trials in session: 16
# 		sub: subj02 fetching condition trials in session: 17
# 		sub: subj02 fetching condition trials in session: 18
# 		sub: subj02 fetching condition trials in session: 19
# 		sub: subj02 fetching condition trials in session: 20
# 		sub: subj02 fetching condition trials in session: 21
# 		sub: subj02 fetching condition trials in session: 22
# 		sub: subj02 fetching condition trials in session: 23
# 		sub: subj02 fetching condition trials in session: 24
# 		sub: subj02 fetching condition trials in session: 25
# 		sub: subj02 fetching condition trials in session: 26
# 		sub: subj02 fetching condition trials in session: 27
# 		sub: subj02 fetching condition trials in session: 28
# 		sub: subj02 fetching condition trials in session: 29
# 		sub: subj02 fetching condition trials in session: 30
# 		sub: subj02 fetching condition trials in session: 31
# 		sub: subj02 fetching condition trials in session: 32
# 		sub: subj02 fetching condition trials in session: 33
# 		sub: subj02 fetching condition trials in session: 34
# 		sub: subj02 fetching condition trials in session: 35
# 		sub: subj02 fetching condition trials in session: 36
# 		sub: subj02 fetching condition trials in session: 37
# 		sub: subj02 fetching condition trials in session: 38
# 		sub: subj02 fetching condition trials in session: 39
# 		sub: subj02 fetching condition trials in session: 40
# 		sub: subj03 fetching condition trials in session: 1
# 		sub: subj03 fetching condition trials in session: 2
# 		sub: subj03 fetching condition trials in session: 3
# 		sub: subj03 fetching condition trials in session: 4
# 		sub: subj03 fetching condition trials in session: 5
# 		sub: subj03 fetching condition trials in session: 6
# 		sub: subj03 fetching condition trials in session: 7
# 		sub: subj03 fetching condition trials in session: 8
# 		sub: subj03 fetching condition trials in session: 9
# 		sub: subj03 fetching condition trials in session: 10
# 		sub: subj03 fetching condition trials in session: 11
# 		sub: subj03 fetching condition trials in session: 12
# 		sub: subj03 fetching condition trials in session: 13
# 		sub: subj03 fetching condition trials in session: 14
# 		sub: subj03 fetching condition trials in session: 15
# 		sub: subj03 fetching condition trials in session: 16
# 		sub: subj03 fetching condition trials in session: 17
# 		sub: subj03 fetching condition trials in session: 18
# 		sub: subj03 fetching condition trials in session: 19
# 		sub: subj03 fetching condition trials in session: 20
# 		sub: subj03 fetching condition trials in session: 21
# 		sub: subj03 fetching condition trials in session: 22
# 		sub: subj03 fetching condition trials in session: 23
# 		sub: subj03 fetching condition trials in session: 24
# 		sub: subj03 fetching condition trials in session: 25
# 		sub: subj03 fetching condition trials in session: 26
# 		sub: subj03 fetching condition trials in session: 27
# 		sub: subj03 fetching condition trials in session: 28
# 		sub: subj03 fetching condition trials in session: 29
# 		sub: subj03 fetching condition trials in session: 30
# 		sub: subj03 fetching condition trials in session: 31
# 		sub: subj03 fetching condition trials in session: 32
# 		sub: subj04 fetching condition trials in session: 1
# 		sub: subj04 fetching condition trials in session: 2
# 		sub: subj04 fetching condition trials in session: 3
# 		sub: subj04 fetching condition trials in session: 4
# 		sub: subj04 fetching condition trials in session: 5
# 		sub: subj04 fetching condition trials in session: 6
# 		sub: subj04 fetching condition trials in session: 7
# 		sub: subj04 fetching condition trials in session: 8
# 		sub: subj04 fetching condition trials in session: 9
# 		sub: subj04 fetching condition trials in session: 10
# 		sub: subj04 fetching condition trials in session: 11
# 		sub: subj04 fetching condition trials in session: 12
# 		sub: subj04 fetching condition trials in session: 13
# 		sub: subj04 fetching condition trials in session: 14
# 		sub: subj04 fetching condition trials in session: 15
# 		sub: subj04 fetching condition trials in session: 16
# 		sub: subj04 fetching condition trials in session: 17
# 		sub: subj04 fetching condition trials in session: 18
# 		sub: subj04 fetching condition trials in session: 19
# 		sub: subj04 fetching condition trials in session: 20
# 		sub: subj04 fetching condition trials in session: 21
# 		sub: subj04 fetching condition trials in session: 22
# 		sub: subj04 fetching condition trials in session: 23
# 		sub: subj04 fetching condition trials in session: 24
# 		sub: subj04 fetching condition trials in session: 25
# 		sub: subj04 fetching condition trials in session: 26
# 		sub: subj04 fetching condition trials in session: 27
# 		sub: subj04 fetching condition trials in session: 28
# 		sub: subj04 fetching condition trials in session: 29
# 		sub: subj04 fetching condition trials in session: 30
# 		sub: subj05 fetching condition trials in session: 1
# 		sub: subj05 fetching condition trials in session: 2
# 		sub: subj05 fetching condition trials in session: 3
# 		sub: subj05 fetching condition trials in session: 4
# 		sub: subj05 fetching condition trials in session: 5
# 		sub: subj05 fetching condition trials in session: 6
# 		sub: subj05 fetching condition trials in session: 7
# 		sub: subj05 fetching condition trials in session: 8
# 		sub: subj05 fetching condition trials in session: 9
# 		sub: subj05 fetching condition trials in session: 10
# 		sub: subj05 fetching condition trials in session: 11
# 		sub: subj05 fetching condition trials in session: 12
# 		sub: subj05 fetching condition trials in session: 13
# 		sub: subj05 fetching condition trials in session: 14
# 		sub: subj05 fetching condition trials in session: 15
# 		sub: subj05 fetching condition trials in session: 16
# 		sub: subj05 fetching condition trials in session: 17
# 		sub: subj05 fetching condition trials in session: 18
# 		sub: subj05 fetching condition trials in session: 19
# 		sub: subj05 fetching condition trials in session: 20
# 		sub: subj05 fetching condition trials in session: 21
# 		sub: subj05 fetching condition trials in session: 22
# 		sub: subj05 fetching condition trials in session: 23
# 		sub: subj05 fetching condition trials in session: 24
# 		sub: subj05 fetching condition trials in session: 25
# 		sub: subj05 fetching condition trials in session: 26
# 		sub: subj05 fetching condition trials in session: 27
# 		sub: subj05 fetching condition trials in session: 28
# 		sub: subj05 fetching condition trials in session: 29
# 		sub: subj05 fetching condition trials in session: 30
# 		sub: subj05 fetching condition trials in session: 31
# 		sub: subj05 fetching condition trials in session: 32
# 		sub: subj05 fetching condition trials in session: 33
# 		sub: subj05 fetching condition trials in session: 34
# 		sub: subj05 fetching condition trials in session: 35
# 		sub: subj05 fetching condition trials in session: 36
# 		sub: subj05 fetching condition trials in session: 37
# 		sub: subj05 fetching condition trials in session: 38
# 		sub: subj05 fetching condition trials in session: 39
# 		sub: subj05 fetching condition trials in session: 40
# 		sub: subj06 fetching condition trials in session: 1
# 		sub: subj06 fetching condition trials in session: 2
# 		sub: subj06 fetching condition trials in session: 3
# 		sub: subj06 fetching condition trials in session: 4
# 		sub: subj06 fetching condition trials in session: 5
# 		sub: subj06 fetching condition trials in session: 6
# 		sub: subj06 fetching condition trials in session: 7
# 		sub: subj06 fetching condition trials in session: 8
# 		sub: subj06 fetching condition trials in session: 9
# 		sub: subj06 fetching condition trials in session: 10
# 		sub: subj06 fetching condition trials in session: 11
# 		sub: subj06 fetching condition trials in session: 12
# 		sub: subj06 fetching condition trials in session: 13
# 		sub: subj06 fetching condition trials in session: 14
# 		sub: subj06 fetching condition trials in session: 15
# 		sub: subj06 fetching condition trials in session: 16
# 		sub: subj06 fetching condition trials in session: 17
# 		sub: subj06 fetching condition trials in session: 18
# 		sub: subj06 fetching condition trials in session: 19
# 		sub: subj06 fetching condition trials in session: 20
# 		sub: subj06 fetching condition trials in session: 21
# 		sub: subj06 fetching condition trials in session: 22
# 		sub: subj06 fetching condition trials in session: 23
# 		sub: subj06 fetching condition trials in session: 24
# 		sub: subj06 fetching condition trials in session: 25
# 		sub: subj06 fetching condition trials in session: 26
# 		sub: subj06 fetching condition trials in session: 27
# 		sub: subj06 fetching condition trials in session: 28
# 		sub: subj06 fetching condition trials in session: 29
# 		sub: subj06 fetching condition trials in session: 30
# 		sub: subj06 fetching condition trials in session: 31
# 		sub: subj06 fetching condition trials in session: 32
# 		sub: subj07 fetching condition trials in session: 1
# 		sub: subj07 fetching condition trials in session: 2
# 		sub: subj07 fetching condition trials in session: 3
# 		sub: subj07 fetching condition trials in session: 4
# 		sub: subj07 fetching condition trials in session: 5
# 		sub: subj07 fetching condition trials in session: 6
# 		sub: subj07 fetching condition trials in session: 7
# 		sub: subj07 fetching condition trials in session: 8
# 		sub: subj07 fetching condition trials in session: 9
# 		sub: subj07 fetching condition trials in session: 10
# 		sub: subj07 fetching condition trials in session: 11
# 		sub: subj07 fetching condition trials in session: 12
# 		sub: subj07 fetching condition trials in session: 13
# 		sub: subj07 fetching condition trials in session: 14
# 		sub: subj07 fetching condition trials in session: 15
# 		sub: subj07 fetching condition trials in session: 16
# 		sub: subj07 fetching condition trials in session: 17
# 		sub: subj07 fetching condition trials in session: 18
# 		sub: subj07 fetching condition trials in session: 19
# 		sub: subj07 fetching condition trials in session: 20
# 		sub: subj07 fetching condition trials in session: 21
# 		sub: subj07 fetching condition trials in session: 22
# 		sub: subj07 fetching condition trials in session: 23
# 		sub: subj07 fetching condition trials in session: 24
# 		sub: subj07 fetching condition trials in session: 25
# 		sub: subj07 fetching condition trials in session: 26
# 		sub: subj07 fetching condition trials in session: 27
# 		sub: subj07 fetching condition trials in session: 28
# 		sub: subj07 fetching condition trials in session: 29
# 		sub: subj07 fetching condition trials in session: 30
# 		sub: subj07 fetching condition trials in session: 31
# 		sub: subj07 fetching condition trials in session: 32
# 		sub: subj07 fetching condition trials in session: 33
# 		sub: subj07 fetching condition trials in session: 34
# 		sub: subj07 fetching condition trials in session: 35
# 		sub: subj07 fetching condition trials in session: 36
# 		sub: subj07 fetching condition trials in session: 37
# 		sub: subj07 fetching condition trials in session: 38
# 		sub: subj07 fetching condition trials in session: 39
# 		sub: subj07 fetching condition trials in session: 40
# 		sub: subj08 fetching condition trials in session: 1
# 		sub: subj08 fetching condition trials in session: 2
# 		sub: subj08 fetching condition trials in session: 3
# 		sub: subj08 fetching condition trials in session: 4
# 		sub: subj08 fetching condition trials in session: 5
# 		sub: subj08 fetching condition trials in session: 6
# 		sub: subj08 fetching condition trials in session: 7
# 		sub: subj08 fetching condition trials in session: 8
# 		sub: subj08 fetching condition trials in session: 9
# 		sub: subj08 fetching condition trials in session: 10
# 		sub: subj08 fetching condition trials in session: 11
# 		sub: subj08 fetching condition trials in session: 12
# 		sub: subj08 fetching condition trials in session: 13
# 		sub: subj08 fetching condition trials in session: 14
# 		sub: subj08 fetching condition trials in session: 15
# 		sub: subj08 fetching condition trials in session: 16
# 		sub: subj08 fetching condition trials in session: 17
# 		sub: subj08 fetching condition trials in session: 18
# 		sub: subj08 fetching condition trials in session: 19
# 		sub: subj08 fetching condition trials in session: 20
# 		sub: subj08 fetching condition trials in session: 21
# 		sub: subj08 fetching condition trials in session: 22
# 		sub: subj08 fetching condition trials in session: 23
# 		sub: subj08 fetching condition trials in session: 24
# 		sub: subj08 fetching condition trials in session: 25
# 		sub: subj08 fetching condition trials in session: 26
# 		sub: subj08 fetching condition trials in session: 27
# 		sub: subj08 fetching condition trials in session: 28
# 		sub: subj08 fetching condition trials in session: 29
# 		sub: subj08 fetching condition trials in session: 30
# (907,)
# [[-0.48904547 -0.6321048 ]
#  [ 0.05454651  0.70571345]
#  [-0.43584672 -0.58906263]
#  ...
#  [-0.5720981  -0.5707307 ]
#  [ 0.4883913   0.5600432 ]
#  [ 0.3847739   0.46473083]]
# [[ 0.00806928 -0.7572817 ]
#  [ 0.4076677  -0.40104052]
#  [-0.61324996 -0.56195503]
#  ...
#  [ 0.28770244 -0.6456871 ]
#  [-0.6414153   0.29659677]
#  [ 0.40534177  0.01031652]]
# [[ 0.01625607 -0.57528704]
#  [ 0.18775472  0.66169876]
#  [-0.7920724  -0.23686317]
#  ...
#  [-0.76466393 -0.2328792 ]
#  [ 0.4752489   0.67938405]
#  [-0.07587725 -0.39778942]]
# [[-0.43153003 -0.0264073 ]
#  [-0.07680967 -0.53455365]
#  [ 0.6410322  -0.48972103]
#  ...
#  [-0.6190398  -0.5749555 ]
#  [ 0.4271968  -0.4626026 ]
#  [-0.20331939 -0.11802859]]
# [[-0.26468593 -0.02610916]
#  [-0.01554198  0.82191086]
#  [-0.7282502  -0.34517598]
#  ...
#  [-0.19735079 -0.6040885 ]
#  [-0.54201376  0.6034352 ]
#  [-0.48633546  0.40079314]]
# [[ 0.04787785  0.75354695]
#  [ 0.12887517  0.49418166]
#  [-0.7183236   0.14104222]
#  ...
#  [ 0.25027773 -0.60873365]
#  [-0.28760958  0.47812727]
#  [-0.67110175  0.22045398]]
# [[-0.02833983 -0.7684691 ]
#  [ 0.54797167 -0.49954993]
#  [-0.51584333 -0.3826241 ]
#  ...
#  [-0.7988269   0.02146127]
#  [ 0.30555865  0.54828495]
#  [ 0.50682324 -0.62898576]]
# [[ 1.          1.        ]
#  [ 0.6541633   0.75635332]
#  [ 0.36456779  0.93117684]
#  [ 0.53622597  0.84407449]
#  [ 0.68344992 -0.72999746]
#  [ 0.72568947  0.68802243]
#  [ 0.427239    0.90413874]
#  [-0.29617682  0.95513314]]

# %%
cos_sin    #Y's sould probably be flipped
# Out:
# array([[ 1.        ,  1.        ],
#        [ 0.6541633 ,  0.75635332],
#        [ 0.36456779,  0.93117684],
#        [ 0.53622597,  0.84407449],
#        [ 0.68344992, -0.72999746],
#        [ 0.72568947,  0.68802243],
#        [ 0.427239  ,  0.90413874],
#        [-0.29617682,  0.95513314]])

# %%
models_subs = {}
models = ['oself']
columns = ["x0", "y0", "sigma", "slope", "intercept", "test_var_explained", "var_explained", "mds_ecc", "mds_ang", "roi", "fit_with"]
model_study = 'oself'
mode = "train"
rotated = True

#cos_sin = get_prefered_xy(subj_list) # save that and open it matlab 
#print(cos_sin)


for i, sub in enumerate(subj_list):
    models_subs[sub] = {}
    for m in models:
        if rotated:
            m_file = os.path.join(models_dir, f'best_fits_{m}_{sub}_{mode}_basevoxel_rotated.npy')
        if not rotated:
            m_file = os.path.join(models_dir, f'best_fits_{m}_{sub}_{mode}_basevoxel_notrotated.npy')
        models_subs[sub][m] = pd.DataFrame(np.load(m_file, allow_pickle=True), columns=columns)
        models_subs[sub][m][columns[:-2]] = models_subs[sub][m][columns[:-2]].astype(np.float32)
        models_subs[sub][m]['x0_prefered'] = models_subs[sub][m]['x0'] * cos_sin[i, 0] # the mds have different dimension -> so problem 
        models_subs[sub][m]['y0_prefered'] = models_subs[sub][m]['y0'] * cos_sin[i, 1]
        models_subs[sub][m]['distance'] = np.sqrt(models_subs[sub][m]['x0']**2 + models_subs[sub][m]['y0']**2)
        models_subs[sub][m]['distance_prefered'] = np.sqrt(models_subs[sub][m]['x0_prefered']**2 + models_subs[sub][m]['y0_prefered']**2)
    sub_m_study = models_subs[sub][model_study]

hier_index = pd.MultiIndex.from_arrays(
    [
        np.tile(list(rois.keys()), len(models_subs)),
        np.repeat(list(models_subs.keys()), len(rois.keys())),
    ],
    names =["roi", "sub"]
)
models_subs["subj01"]["oself"]["test_var_explained"]

# check distribution of values in VO-1s for common conditions
# Out:
# 0        0.000676
# 1       -0.000803
# 2       -0.002064
# 3       -0.001289
# 4       -0.002998
#            ...
# 33792    0.010695
# 33793    0.005295
# 33794    0.008918
# 33795    0.006280
# 33796    0.006490
# Name: test_var_explained, Length: 33797, dtype: float32

# %%
models_subs
# Out:
# {'subj01': {'oself':              x0        y0     sigma      slope  intercept  test_var_explained  \
#   0      0.371848 -0.624069  6.235634  30.357092 -30.137138            0.000676
#   1      0.418255 -0.594880  6.208899  25.832947 -25.632463           -0.000803
#   2      0.502787 -0.546511  4.808846  12.609944 -12.428826           -0.002064
#   2               -0.000636       0.004761  0.354631  2.884899  V1       V1
#   3               -0.001304       0.003858  0.344653  0.749486  V1       V1
#   4               -0.001504       0.004088  0.344735  0.602630  V1       V1
#   ...                   ...            ...       ...       ...  ..      ...
#   28488            0.005639       0.050997  0.398481 -0.206107  V1       V1
#   28489            0.001599       0.124376  0.424107 -2.632053  V1       V1
#   28490           -0.000536       0.099236  0.400338 -2.628390  V1       V1
#   28491            0.012034       0.079053  0.790947  2.542051  V1       V1
#   28492            0.014579       0.077494  0.687251 -0.520174  V1       V1
#
#          x0_prefered  y0_prefered  distance  distance_prefered
#   0        -0.311589     0.306799  0.620066           0.437280
#   1         0.094745     0.242765  0.360293           0.260598
#   2         0.084177     0.342536  0.485124           0.352727
#   3         0.061861    -0.070999  0.132860           0.094168
#   4         0.062074    -0.096368  0.160237           0.114629
#   ...            ...          ...       ...                ...
#   28488    -0.150038    -0.766497  1.072704           0.781044
#   28489    -0.179883     0.343861  0.539589           0.388070
#   28490    -0.152329     0.288702  0.453965           0.326425
#   28491     0.490469     0.766497  1.271811           0.909988
#   28492    -0.411049    -0.766497  1.210050           0.869758
#
#   [28493 rows x 15 columns]},
#  'subj06': {'oself':              x0        y0     sigma      slope  intercept  test_var_explained  \
#   0      0.074486  1.005202  0.019097   2.360168  -0.003265            0.001054
#   1      0.262727  1.050000  5.075896   9.722354  -9.627235           -0.002153
#   2     -0.353394 -1.050000  6.183163  11.000331 -10.918475            0.001414
#   3     -0.275097 -1.050000  9.477070  23.652309 -23.581118            0.000226
#   4     -0.340478 -0.398034  3.920230   5.147373  -5.055483            0.002579
#   ...         ...       ...       ...        ...        ...                 ...
#   38168 -1.050000 -1.050000  0.855524   0.513754  -0.228079            0.009382
#   38169 -0.742118 -1.050000  0.692650   0.344926  -0.161477            0.000999
#   38170  1.050000  1.050000  9.015799  19.964844 -19.779116           -0.003870
#   38171  1.050000  1.050000  9.148994  19.214457 -19.041363           -0.001019
#   38172 -1.048401 -0.502460  0.537885   0.348369  -0.071642            0.003242
#
#          var_explained   mds_ecc   mds_ang roi fit_with  x0_prefered  \
#   0           0.000568  1.052639  0.073966  V1       V1     0.054054
#   1           0.004819  1.082370  0.245182  V1       V1     0.190658
#   2           0.004527  1.107875 -2.816936  V1       V1    -0.256454
#   3           0.002682  1.085439 -2.885355  V1       V1    -0.199635
#   4           0.005565  1.103823 -2.433972  V1       V1    -0.247081
#   ...              ...       ...       ...  ..      ...          ...
#   38168       0.024685  1.484924 -2.356194  V1       V1    -0.761974
#   38169       0.013984  1.285784 -2.526331  V1       V1    -0.538547
#   38170       0.019834  1.484924  0.785398  V1       V1     0.761974
#   38171       0.017313  1.484924  0.785398  V1       V1     0.761974
#   38172       0.010563  1.483794 -2.017718  V1       V1    -0.760814
#
#          y0_prefered  distance  distance_prefered
#   0         0.691602  1.007958           0.693711
#   1         0.722423  1.082370           0.747159
#   2        -0.722423  1.107875           0.766593
#   3        -0.722423  1.085439           0.749500
#   4        -0.273856  0.523791           0.368845
#   ...            ...       ...                ...
#   38168    -0.722423  1.484924           1.050000
#   38169    -0.722423  1.285783           0.901071
#   38170     0.722423  1.484924           1.050000
#   38171     0.722423  1.484924           1.050000
#   38172    -0.345704  1.162588           0.835673
#
#   [38173 rows x 15 columns]},
#  'subj07': {'oself':              x0        y0     sigma      slope  intercept  test_var_explained  \
#   0     -0.100500  0.072007  3.249743   7.391566  -7.227013            0.003321
#   1     -0.139173  0.210708  3.910069  10.110271  -9.952690            0.002244
#   2     -0.156825  0.423891  4.566803  13.642355 -13.484928            0.000392
#   3     -0.048920 -0.071705  4.703063  16.783773 -16.604736            0.003296
#   4     -0.125210  0.347291  3.166496   6.824042  -6.661595            0.001495
#   ...         ...       ...       ...        ...        ...                 ...
#   27557  0.667945  0.642688  6.073670  23.002363 -22.721804           -0.005275
#   27558  0.731275  0.673268  6.242153  22.916082 -22.627941           -0.001411
#   27559  0.669591  0.631902  5.970104  22.089359 -21.809916           -0.003870
#   27560  0.782691  0.311618  5.577152  16.202332 -15.924440           -0.009016
#   27561  0.804344  0.553888  6.145358  20.391760 -20.094194           -0.006394
#
#          var_explained   mds_ecc   mds_ang roi fit_with  x0_prefered  \
#   0           0.009496  0.233448 -0.949088  V1       V1    -0.042937
#   1           0.010146  0.252521 -0.583725  V1       V1    -0.059460
#   2           0.010875  0.262663 -0.354349  V1       V1    -0.067002
#   3           0.009509  0.216312 -2.542889  V1       V1    -0.020901
#   4           0.009878  0.245102 -0.346028  V1       V1    -0.053495
#   ...              ...       ...       ...  ..      ...          ...
#   27557       0.061338  0.700391  0.804666  V1       V1     0.285372
#   27558       0.065017  0.761026  0.826674  V1       V1     0.312429
#   27559       0.061484  0.701962  0.814349  V1       V1     0.286076
#   27560       0.059859  0.810557  1.191898  V1       V1     0.334396
#   27561       0.065955  0.831484  0.967748  V1       V1     0.343647
#
#          y0_prefered  distance  distance_prefered
#   0         0.065105  0.123633           0.077989
#   1         0.190509  0.252521           0.199572
#   2         0.383256  0.451970           0.389069
#   3        -0.064832  0.086803           0.068117
#   4         0.313999  0.369173           0.318523
#   ...            ...       ...                ...
#   27557     0.581079  0.926930           0.647372
#   27558     0.608728  0.994009           0.684224
#   27559     0.571327  0.920680           0.638947
#   27560     0.281746  0.842444           0.437266
#   27561     0.500792  0.976607           0.607359
#
#   [27562 rows x 15 columns]},
#  'subj08': {'oself':              x0        y0     sigma      slope  intercept  test_var_explained  \
#   0     -0.901820 -0.763487  7.516421  25.809818 -25.511490           -0.034455
#   1      0.437396  0.240939  0.045332   0.409457   0.007334           -0.000308
#   2     -1.049998 -0.881221  4.164366   6.876918  -6.572504           -0.034003
#   3     -1.050000 -0.836959  5.125771  10.811510 -10.494720           -0.035639
#   4     -0.865687 -0.813583  5.210138  11.966623 -11.698077           -0.029578
#   ...         ...       ...       ...        ...        ...                 ...
#   32531  1.050000 -0.310249  0.843962   0.553481  -0.238974            0.019086
#   32532  1.049999 -0.462079  0.702664   0.416885  -0.139794            0.011739
#   32533  1.049977 -0.643463  0.651665   0.234265  -0.064435            0.002508
#   32534 -1.049996  1.050000  4.667642   0.339112  -0.318926           -0.001999
#   32535  1.050000 -0.428777  0.959634   0.464294  -0.230898            0.002966
#
#          var_explained   mds_ecc   mds_ang    roi fit_with  x0_prefered  \
#   0           0.055947  0.933451 -2.273318     V2       V2     0.267098
#   1           0.000350  0.499367  1.067301     V2       V2    -0.129547
#   2           0.054398  1.077287 -2.269022     V2       V2     0.310985
#   3           0.060089  1.077289 -2.243768     V2       V2     0.310986
#   4           0.048685  0.898591 -2.325177     V2       V2     0.256396
#   ...              ...       ...       ...    ...      ...          ...
#   32531       0.031650  1.484924  1.858097  PHC-2    PHC-2    -0.310986
#   32532       0.018869  1.484924  1.985367  PHC-2    PHC-2    -0.310985
#   32533       0.005887  1.484908  2.120600  PHC-2    PHC-2    -0.310979
#   32534       0.000081  1.484921 -0.785396  PHC-2    PHC-2     0.310984
#   32535       0.019398  1.484924  1.958488  PHC-2    PHC-2    -0.310986
#
#          y0_prefered  distance  distance_prefered
#   0        -0.729232  1.181605           0.776609
#   1         0.230129  0.499367           0.264087
#   2        -0.841684  1.370783           0.897298
#   3        -0.799407  1.342758           0.857767
#   4        -0.777080  1.187994           0.818286
#   ...            ...       ...                ...
#   32531    -0.296329  1.094876           0.429561
#   32532    -0.441347  1.147177           0.539907
#   32533    -0.614593  1.231461           0.688790
#   32534     1.002890  1.484921           1.050000
#   32535    -0.409539  1.134174           0.514232
#
#   [32536 rows x 15 columns]}}

# %%
hemis = ['lh', 'rh']
fields = columns
fields.append('x0_prefered')
fields.append('y0_prefered')
if rotated:
    rotation = "rotated"
if not rotated: 
    rotation = "notrotated"


for model in models:
    for sub, sessions in subjects_sessions.values():
        m = models_subs[sub][model]
        print(f'------ EXPORTING MODEL FOR {sub}')
        for f in fields:
            print(f'\t{f}')
            s = -1
            for hemi in hemis:
                print(f'\t\t{hemi}')
                
                if sub == 'subj06' or sub == 'subj08':
                    maskdata_long_file = os.path.join(data_dir, 'mask', sub, f'{hemi}.{sub}.nans.testrois.mgz')
                else:
                    maskdata_long_file = os.path.join(data_dir, 'mask', sub, f'{hemi}.{sub}.testrois.mgz')
                maskdata_long = nib.load(maskdata_long_file).get_fdata().squeeze()
              #  print(maskdata_long.shape)
        
                maskdata_file = os.path.join(data_dir, 'mask', sub, f'{hemi}.short.reduced.{sub}.testrois.npy')
                maskdata = np.load(maskdata_file, allow_pickle=True).astype(int)

                data_out_file = os.path.join(results_dir, sub, f'{hemi}.{model}.{f}.{rotation}.mgz')
                label_out_file = os.path.join(label_dir,'freesurfer', sub, 'label', f'{hemi}.{model}.{f}.{rotation}.mgz') # annoying but necessary for matlab output
                if os.path.exists(data_out_file):
                    pass
                data_out = np.zeros(maskdata_long.shape)
             
                wrongs = []
                for i in range(maskdata_long.shape[0]):
                    voxel = int(maskdata_long[i])
                    if voxel==0 or voxel > 15:
                        continue
                    s += 1
                    if sior_long[voxel] in to_reduce.keys():
                        roi = rois[to_reduce[sior_long[voxel]]]
                    else:
                        roi = rois[sior_long[voxel]]
                  #  roi = rois[sior[voxel]]
                    # prove that the order is maintained
                    if roi != rois[m.iloc[s].roi]:
                        print(f'{i}: {roi} != {rois[m.iloc[s].roi]}')
                        wrongs.append(i)
                    if f in ['roi', 'fit_with']:
                        data_out[i] = rois[m.iloc[s][f]]
                    elif f == 'mds_ang':
                        data_out[i] = math.degrees(m.iloc[s][f]) + 180
                    elif f == 'intercept':
                        data_out[i] = m.iloc[s][f] + abs(m[f].min()) + 1e-08
                    elif f in ['x0', 'y0', 'x0_prefered', 'y0_prefered']:
                        data_out[i] = m.iloc[s][f] + 1.1
                    elif f in ['var_explained', 'test_var_explained']:
                        data_out[i] = m.iloc[s][f]  + 1 # Add 1 for the variance explain, so we can still mask the non relevant value and plot the "negative" variance
                    else:
                        data_out[i] = m.iloc[s][f]  
                img = nib.Nifti1Image(np.expand_dims(data_out, axis=(1, 2)), np.eye(4))

                nib.loadsave.save(img, data_out_file)
                nib.loadsave.save(img, label_out_file)
                if f == 'mds_ang':
                    for ang in [45, 90, 135, 180, 225, 270, 305]:
                        data_out_file = os.path.join(results_dir, sub, f'{hemi}.{model}.f.{str(ang)}.{rotation}.mgz')
                        label_out_file = os.path.join(label_dir, 'freesurfer', sub, 'label', f'{hemi}.{model}.{f}.{str(ang)}.{rotation}.mgz')
                        data_out_ang = np.copy(data_out)
                        data_out_ang[data_out != 0] += ang
                        data_out_ang = data_out_ang % 360
                        img = nib.Nifti1Image(np.expand_dims(data_out_ang, axis = (1, 2)), np.eye(4))
                        nib.loadsave.save(img, data_out_file)
                        nib.loadsave.save(img, label_out_file)


print('end')
# Out:
# ------ EXPORTING MODEL FOR subj01
# 	x0
# 		lh
# 		rh
# 	y0
# 		lh
# 		rh
# 	sigma
# 		lh
# 		rh
# 	slope
# 		lh
# 		rh
# 	intercept
# 		lh
# 		rh
# 	test_var_explained
# 		lh
# 		rh
# 	var_explained
# 		lh
# 		rh
# 	mds_ecc
# 		lh
# 		rh
# 	mds_ang
# 		lh
# 		rh
# 	roi
# 		lh
# 		rh
# 	fit_with
# 		lh
# 		rh
# 	x0_prefered
# 		lh
# 		rh
# 	y0_prefered
# 		lh
# 		rh
# ------ EXPORTING MODEL FOR subj02
# 	x0
# 		lh
# 		rh
# 	y0
# 		lh
# 		rh
# 	sigma
# 		lh
# 		rh
# 	slope
# 		lh
# 		rh
# 	intercept
# 		lh
# 		rh
# 	test_var_explained
# 		lh
# 		rh
# 	var_explained
# 		lh
# 		rh
# 	mds_ecc
# 		lh
# 		rh
# 	mds_ang
# 		lh
# 		rh
# 	roi
# 		lh
# 		rh
# 	fit_with
# 		lh
# 		rh
# 	x0_prefered
# 		lh
# 		rh
# 	y0_prefered
# 		lh
# 		rh
# ------ EXPORTING MODEL FOR subj03
# 	x0
# 		lh
# 		rh
# 	y0
# 		lh
# 		rh
# 	sigma
# 		lh
# 		rh
# 	slope
# 		lh
# 		rh
# 	intercept
# 		lh
# 		rh
# 	test_var_explained
# 		lh
# 		rh
# 	var_explained
# 		lh
# 		rh
# 	mds_ecc
# 		lh
# 		rh
# 	mds_ang
# 		lh
# 		rh
# 	roi
# 		lh
# 		rh
# 	fit_with
# 		lh
# 		rh
# 	x0_prefered
# 		lh
# 		rh
# 	y0_prefered
# 		lh
# 		rh
# ------ EXPORTING MODEL FOR subj04
# 	x0
# 		lh
# 		rh
# 	y0
# 		lh
# 		rh
# 	sigma
# 		lh
# 		rh
# 	slope
# 		lh
# 		rh
# 	intercept
# 		lh
# 		rh
# 	test_var_explained
# 		lh
# 		rh
# 	var_explained
# 		lh
# 		rh
# 	mds_ecc
# 		lh
# 		rh
# 	mds_ang
# 		lh
# 		rh
# 	roi
# 		lh
# 		rh
# 	fit_with
# 		lh
# 		rh
# 	x0_prefered
# 		lh
# 		rh
# 	y0_prefered
# 		lh
# 		rh
# ------ EXPORTING MODEL FOR subj05
# 	x0
# 		lh
# 		rh
# 	y0
# 		lh
# 		rh
# 	sigma
# 		lh
# 		rh
# 	slope
# 		lh
# 		rh
# 	intercept
# 		lh
# 		rh
# 	test_var_explained
# 		lh
# 		rh
# 	var_explained
# 		lh
# 		rh
# 	mds_ecc
# 		lh
# 		rh
# 	mds_ang
# 		lh
# 		rh
# 	roi
# 		lh
# 		rh
# 	fit_with
# 		lh
# 		rh
# 	x0_prefered
# 		lh
# 		rh
# 	y0_prefered
# 		lh
# 		rh
# ------ EXPORTING MODEL FOR subj06
# 	x0
# 		lh
# 		rh
# 	y0
# 		lh
# 		rh
# 	sigma
# 		lh
# 		rh
# 	slope
# 		lh
# 		rh
# 	intercept
# 		lh
# 		rh
# 	test_var_explained
# 		lh
# 		rh
# 	var_explained
# 		lh
# 		rh
# 	mds_ecc
# 		lh
# 		rh
# 	mds_ang
# 		lh
# 		rh
# 	roi
# 		lh
# 		rh
# 	fit_with
# 		lh
# 		rh
# 	x0_prefered
# 		lh
# 		rh
# 	y0_prefered
# 		lh
# 		rh
# ------ EXPORTING MODEL FOR subj07
# 	x0
# 		lh
# 		rh
# 	y0
# 		lh
# 		rh
# 	sigma
# 		lh
# 		rh
# 	slope
# 		lh
# 		rh
# 	intercept
# 		lh
# 		rh
# 	test_var_explained
# 		lh
# 		rh
# 	var_explained
# 		lh
# 		rh
# 	mds_ecc
# 		lh
# 		rh
# 	mds_ang
# 		lh
# 		rh
# 	roi
# 		lh
# 		rh
# 	fit_with
# 		lh
# 		rh
# 	x0_prefered
# 		lh
# 		rh
# 	y0_prefered
# 		lh
# 		rh
# ------ EXPORTING MODEL FOR subj08
# 	x0
# 		lh
# 		rh
# 	y0
# 		lh
# 		rh
# 	sigma
# 		lh
# 		rh
# 	slope
# 		lh
# 		rh
# 	intercept
# 		lh
# 		rh
# 	test_var_explained
# 		lh
# 		rh
# 	var_explained
# 		lh
# 		rh
# 	mds_ecc
# 		lh
# 		rh
# 	mds_ang
# 		lh
# 		rh
# 	roi
# 		lh
# 		rh
# 	fit_with
# 		lh
# 		rh
# 	x0_prefered
# 		lh
# 		rh
# 	y0_prefered
# 		lh
# 		rh
# end
