# %%
import pandas as pd
import numpy as np
import math
import os
from utils.utils import *
import matplotlib.pyplot as plt
import matplotlib
import random
import scipy as sc
import nibabel as nib

# %%
hemis = ['lh', 'rh']
upscaling_factor = 1.8**3
columns =  ['hemisphere', 
            'subject', 
            'roi', 
            'df', 
            'spearmanr',
            'pvalue']

rois_corr = {
    'V1': [1, 2],
    'V2v': [3],
    'V2d': [4],
    'V3v': [5],
    'V3d': [6],
    'hV4': [7],
    'VO-1': [8],
    'VO-2': [9],
    'PHC-1': [10],
    'PHC-2': [11],
    'LO-1': [12],
    'LO-2': [13],
    'TO-1': [14],
    'TO-2': [15]
}

types = ['string',
        'string',
        'string',
        'int',
        'float',
        'float',
         'float',
        'int', 
        'float',
        'int',
        'float']

significance = 0.05
scaling_factor = 1 / (1.8 ** 3)

# %%
### Fix cortical surface distances for s6 and s8: 
### Remove indices of the upper triangle where there's a nan values 


for sub in ['subj06', 'subj08']:
    nan_mask_file = os.path.join(betas_dir, f"{sub}_betas_nans_mask.npy")
    nan_mask = np.load(nan_mask_file, allow_pickle=True)
    print(nan_mask.shape)
    for hemi in hemis:
        for roi, pointer in rois_corr.items():
            mask_file = os.path.join(mask_dir, sub, f'{hemi}.short.{sub}.testrois.npy')
            mask = np.load(mask_file, allow_pickle=True)
            to_keep = np.isin(mask, pointer)
            if hemi == 'lh':
                current_roi_nans = nan_mask[:mask.shape[0]][to_keep]
            if hemi == 'rh':
                current_roi_nans = nan_mask[-mask.shape[0]:][to_keep]
            if False in current_roi_nans:
                # load files 
                roi_distances_cs_file = os.path.join(label_dir, 'freesurfer', sub,  'label', 'distances',   hemi + '.' + sub + '.dists_wrong.' + roi + '.mat')
                roi_distances_cs = sc.io.loadmat(roi_distances_cs_file)['d_roi']

                #Easy: should work 
                filtered_roi_distances_cs = roi_distances_cs[current_roi_nans][:, current_roi_nans]

                roi_distances_mds_file = os.path.join(dist_dir, sub,  hemi + '.' + "best_roi" + '.' + sub + '.dists.' + roi + '.npy')
                roi_distances_mds = np.load(roi_distances_mds_file, allow_pickle = True).astype(np.float32)
                n_voxels = filtered_roi_distances_cs.shape[0]
                roi_distances_mds = roi_distances_mds.reshape([n_voxels, n_voxels])
                print(filtered_roi_distances_cs.shape)
                print(roi_distances_mds.shape)
# Out:
# (39283,)
# (3318, 3318)
# (3318, 3318)
# (1426, 1426)
# (1426, 1426)
# (1205, 1205)
# (1205, 1205)
# (1548, 1548)
# (1548, 1548)
# (2798, 2798)
# (2798, 2798)
# (1426, 1426)
# (1426, 1426)
# (1413, 1413)
# (1413, 1413)
# (32608,)
# (1152, 1152)
# (1152, 1152)
# (2930, 2930)
# (2930, 2930)

# %%
mask_file = os.path.join(mask_dir, sub, f'short.{sub}.testrois.npy')
mask = np.load(mask_file, allow_pickle=True)
tosel = np.isin(mask, [1, 3])
tosel
# Out:
# array([False, False, False, ..., False, False, False])

# %%
rois_corr
# Out:
# {'V1': [1, 2],
#  'V2v': [3],
#  'V2d': [4],
#  'V3v': [5],
#  'V3d': [6],
#  'hV4': [7],
#  'VO-1': [8],
#  'VO-2': [9],
#  'PHC-1': [10],
#  'PHC-2': [11],
#  'LO-1': [12],
#  'LO-2': [13],
#  'TO-1': [14],
#  'TO-2': [15]}

# %%
def work_spearman_downscaled(a, b, sample_size):
    #sample_size = round(a.shape[0] * factor)
    random_sample = random.sample(range(0, a.shape[0]), round(sample_size)) 
    sample_a = a[random_sample]
    sample_b = b[random_sample]
    results = sc.stats.spearmanr(sample_a, sample_b)
    return results.statistic, results.pvalue
def work_spearman_downscaled_averaged(a, b, sample_size, trials):
    rhos, p_values = [], []
    for i in range(trials):
        rho, p = work_spearman_downscaled(a, b, sample_size)
        rhos.append(rho)
        p_values.append(p)
    return np.median(np.asarray(rho)), np.median(np.asarray(p))

# %%
rois_corr_2 = {
    'V2': [3,4],
    'V3': [5,6],
}

# %%
subj_list
# Out:
# ['subj01',
#  'subj02',
#  'subj03',
#  'subj04',
#  'subj05',
#  'subj06',
#  'subj07',
#  'subj08']

# %%
roi_distances_mds = {}
roi_distances_cs = {}
model = 'best_roi'


distances_file = os.path.join(spatial_dir, f'distances_spearman_joined_{model}.npy')
if os.path.exists(distances_file):
    distances = np.load(distances_file, allow_pickle = True)
    distances = pd.DataFrame(distances, columns = columns)
    distances = distances.astype({c: t for c,t in zip(columns, types)})
else:
    distances = pd.DataFrame(np.zeros([len(subj_list) * 2 * len(rois_corr.keys()), len(columns)]), columns = columns)
    i = 0
    for sub in subj_list:
        if sub == 'subj06' or sub == 'subj08': 
            nan_mask_file = os.path.join(betas_dir, f"{sub}_betas_nans_mask.npy")
            nan_mask = np.load(nan_mask_file, allow_pickle=True)
        for hemi in hemis:
    
            for roi, pointer in rois_corr.items():

                if sub == 'subj06' or sub == 'subj08': 

                    mask_file = os.path.join(mask_dir, sub, f'{hemi}.short.{sub}.testrois.npy')
                    mask = np.load(mask_file, allow_pickle=True)
                    to_keep = np.isin(mask, pointer)
                    if hemi == 'lh':
                        current_roi_nans = nan_mask[:mask.shape[0]][to_keep]
                    if hemi == 'rh':
                        current_roi_nans = nan_mask[-mask.shape[0]:][to_keep]
                    roi_distances_cs_file = os.path.join(label_dir, 'freesurfer', sub,  'label', 'distances',   hemi + '.' + sub + '.dists_wrong.' + roi + '.mat')
                    roi_distances_cs = sc.io.loadmat(roi_distances_cs_file)['d_roi']
                    if current_roi_nans is not None and False in current_roi_nans: 
                        roi_distances_cs = roi_distances_cs[current_roi_nans][:, current_roi_nans]

                else:
                    roi_distances_cs_file = os.path.join(label_dir, 'freesurfer', sub,  'label', 'distances',   hemi + '.' + sub + '.dists.' + roi + '.mat')
                    roi_distances_cs = sc.io.loadmat(roi_distances_cs_file)['d_roi']

                
                roi_distances_mds_file = os.path.join(dist_dir, sub,  hemi + '.' + model + '.' + sub + '.dists.' + roi + '.npy')
                print(roi_distances_mds_file)
                print(os.path.exists(roi_distances_cs_file))
                print(os.path.exists(roi_distances_mds_file))
                
                n_voxels = roi_distances_cs.shape[0]
            
                roi_distances_mds = np.load(roi_distances_mds_file, allow_pickle = True).astype(np.float32)
                roi_distances_mds = roi_distances_mds.reshape([n_voxels, n_voxels])
                triu = np.triu_indices(n_voxels)
   
                roi_distances_cs = roi_distances_cs[triu]
                roi_distances_mds = roi_distances_mds[triu]  

                #print(roi_distances_cs.shape[0])
                sample_n=n_voxels/scaling_factor
                
                scorrelation, pvalues = work_spearman_downscaled_averaged(roi_distances_mds, roi_distances_cs, sample_n, 1000) # take median p value

                # calculate pearson R and pvalue for H0: samples are uncorrelated and normally distributed
    #             correlation, pvalue = sc.stats.pearsonr(x=roi_distances_mds, y = roi_distances_cs)
                df = roi_distances_mds.shape[0] 
                print(scorrelation)
                
                distances.iloc[i] = [hemi, sub, roi, df, scorrelation, pvalues]
                i += 1

    np.save(distances_file, distances)

distances
# Out:
# /media/Working/stan-thesis/projects/distances/subj01/lh.best_roi.subj01.dists.V1.npy
# True
# True
# 0.31877155743990904
# /media/Working/stan-thesis/projects/distances/subj01/lh.best_roi.subj01.dists.V2v.npy
# True
# True
# 0.45813580007411003
# /media/Working/stan-thesis/projects/distances/subj01/lh.best_roi.subj01.dists.V2d.npy
# True
# True
# 0.43882122796756734
# /media/Working/stan-thesis/projects/distances/subj01/lh.best_roi.subj01.dists.V3v.npy
# True
# True
# 0.4210669425886776
# /media/Working/stan-thesis/projects/distances/subj01/lh.best_roi.subj01.dists.V3d.npy
# True
# True
# 0.32300207000354536
# /media/Working/stan-thesis/projects/distances/subj01/lh.best_roi.subj01.dists.hV4.npy
# True
# True
# 0.17609000722346307
# /media/Working/stan-thesis/projects/distances/subj01/lh.best_roi.subj01.dists.VO-1.npy
# True
# True
# 0.1244031144903287
# /media/Working/stan-thesis/projects/distances/subj01/lh.best_roi.subj01.dists.VO-2.npy
# True
# True
# 0.3733793655550177
# /media/Working/stan-thesis/projects/distances/subj01/lh.best_roi.subj01.dists.PHC-1.npy
# True
# True
# 0.36784280081542736
# /media/Working/stan-thesis/projects/distances/subj01/lh.best_roi.subj01.dists.PHC-2.npy
# True
# True
# 0.33049835977323266
# /media/Working/stan-thesis/projects/distances/subj01/lh.best_roi.subj01.dists.LO-1.npy
# True
# True
# 0.11647500027111428
# /media/Working/stan-thesis/projects/distances/subj01/lh.best_roi.subj01.dists.LO-2.npy
# True
# True
# 0.12441010398067805
# /media/Working/stan-thesis/projects/distances/subj01/lh.best_roi.subj01.dists.TO-1.npy
# True
# True
# 0.3146608541956811
# /media/Working/stan-thesis/projects/distances/subj01/lh.best_roi.subj01.dists.TO-2.npy
# True
# True
# 0.34121445048056
# /media/Working/stan-thesis/projects/distances/subj01/rh.best_roi.subj01.dists.V1.npy
# True
# True
# 0.39739020574215655
# /media/Working/stan-thesis/projects/distances/subj01/rh.best_roi.subj01.dists.V2v.npy
# True
# True
# 0.2978813589608044
# /media/Working/stan-thesis/projects/distances/subj01/rh.best_roi.subj01.dists.V2d.npy
# True
# True
# 0.46438796656350073
# /media/Working/stan-thesis/projects/distances/subj01/rh.best_roi.subj01.dists.V3v.npy
# True
# True
# 0.3857351571776539
# /media/Working/stan-thesis/projects/distances/subj01/rh.best_roi.subj01.dists.V3d.npy
# True
# True
# 0.3305584474520606
# /media/Working/stan-thesis/projects/distances/subj01/rh.best_roi.subj01.dists.hV4.npy
# True
# True
# 0.15232108754496682
# /media/Working/stan-thesis/projects/distances/subj01/rh.best_roi.subj01.dists.VO-1.npy
# True
# True
# 0.0460127146047025
# /media/Working/stan-thesis/projects/distances/subj01/rh.best_roi.subj01.dists.VO-2.npy
# True
# True
# 0.2314478138664686
# /media/Working/stan-thesis/projects/distances/subj01/rh.best_roi.subj01.dists.PHC-1.npy
# True
# True
# 0.2332148951031472
# /media/Working/stan-thesis/projects/distances/subj01/rh.best_roi.subj01.dists.PHC-2.npy
# True
# True
# 0.38371246202769504
# /media/Working/stan-thesis/projects/distances/subj01/rh.best_roi.subj01.dists.LO-1.npy
# True
# True
# 0.20132204084421734
# /media/Working/stan-thesis/projects/distances/subj01/rh.best_roi.subj01.dists.LO-2.npy
# True
# True
# 0.18704796020558867
# /media/Working/stan-thesis/projects/distances/subj01/rh.best_roi.subj01.dists.TO-1.npy
# True
# True
# 0.22261358585869287
# /media/Working/stan-thesis/projects/distances/subj01/rh.best_roi.subj01.dists.TO-2.npy
# True
# True
# 0.21813340731824674
# /media/Working/stan-thesis/projects/distances/subj02/lh.best_roi.subj02.dists.V1.npy
# True
# True
# 0.24569240643605209
# /media/Working/stan-thesis/projects/distances/subj02/lh.best_roi.subj02.dists.V2v.npy
# True
# True
# 0.3058809545399589
# /media/Working/stan-thesis/projects/distances/subj02/lh.best_roi.subj02.dists.V2d.npy
# True
# True
# 0.14965599001506208
# /media/Working/stan-thesis/projects/distances/subj02/lh.best_roi.subj02.dists.V3v.npy
# True
# True
# 0.19345907040259794
# /media/Working/stan-thesis/projects/distances/subj02/lh.best_roi.subj02.dists.V3d.npy
# True
# True
# 0.26523237760397217
# /media/Working/stan-thesis/projects/distances/subj02/lh.best_roi.subj02.dists.hV4.npy
# True
# True
# 0.18846035491110377
# /media/Working/stan-thesis/projects/distances/subj02/lh.best_roi.subj02.dists.VO-1.npy
# True
# True
# 0.08045832229728324
# /media/Working/stan-thesis/projects/distances/subj02/lh.best_roi.subj02.dists.VO-2.npy
# True
# True
# 0.3544504172871123
# /media/Working/stan-thesis/projects/distances/subj02/lh.best_roi.subj02.dists.PHC-1.npy
# True
# True
# 0.32887616839760714
# /media/Working/stan-thesis/projects/distances/subj02/lh.best_roi.subj02.dists.PHC-2.npy
# True
# True
# 0.3524981392622854
# /media/Working/stan-thesis/projects/distances/subj02/lh.best_roi.subj02.dists.LO-1.npy
# True
# True
# 0.18046800778083155
# /media/Working/stan-thesis/projects/distances/subj02/lh.best_roi.subj02.dists.LO-2.npy
# True
# True
# 0.21474262254771156
# /media/Working/stan-thesis/projects/distances/subj02/lh.best_roi.subj02.dists.TO-1.npy
# True
# True
# 0.1215268022617167
# /media/Working/stan-thesis/projects/distances/subj02/lh.best_roi.subj02.dists.TO-2.npy
# True
# True
# 0.28865749290291715
# /media/Working/stan-thesis/projects/distances/subj02/rh.best_roi.subj02.dists.V1.npy
# True
# True
# 0.3263079623838433
# /media/Working/stan-thesis/projects/distances/subj02/rh.best_roi.subj02.dists.V2v.npy
# True
# True
# 0.1499645030353558
# /media/Working/stan-thesis/projects/distances/subj02/rh.best_roi.subj02.dists.V2d.npy
# True
# True
# 0.18914052805681017
# /media/Working/stan-thesis/projects/distances/subj02/rh.best_roi.subj02.dists.V3v.npy
# True
# True
# 0.3703580554525338
# /media/Working/stan-thesis/projects/distances/subj02/rh.best_roi.subj02.dists.V3d.npy
# True
# True
# 0.25799347666584815
# /media/Working/stan-thesis/projects/distances/subj02/rh.best_roi.subj02.dists.hV4.npy
# True
# True
# 0.17518308915675546
# /media/Working/stan-thesis/projects/distances/subj02/rh.best_roi.subj02.dists.VO-1.npy
# True
# True
# 0.18572161923624306
# /media/Working/stan-thesis/projects/distances/subj02/rh.best_roi.subj02.dists.VO-2.npy
# True
# True
# 0.17360540228861934
# /media/Working/stan-thesis/projects/distances/subj02/rh.best_roi.subj02.dists.PHC-1.npy
# True
# True
# 0.09288591263182853
# /media/Working/stan-thesis/projects/distances/subj02/rh.best_roi.subj02.dists.PHC-2.npy
# True
# True
# 0.3213631943052016
# /media/Working/stan-thesis/projects/distances/subj02/rh.best_roi.subj02.dists.LO-1.npy
# True
# True
# 0.07403756412577549
# /media/Working/stan-thesis/projects/distances/subj02/rh.best_roi.subj02.dists.LO-2.npy
# True
# True
# 0.28100262463437176
# /media/Working/stan-thesis/projects/distances/subj02/rh.best_roi.subj02.dists.TO-1.npy
# True
# True
# 0.11334378014185417
# /media/Working/stan-thesis/projects/distances/subj02/rh.best_roi.subj02.dists.TO-2.npy
# True
# True
# 0.31983226674580123
# /media/Working/stan-thesis/projects/distances/subj03/lh.best_roi.subj03.dists.V1.npy
# True
# True
# 0.3351903597288607
# /media/Working/stan-thesis/projects/distances/subj03/lh.best_roi.subj03.dists.V2v.npy
# True
# True
# 0.48046640571765453
# /media/Working/stan-thesis/projects/distances/subj03/lh.best_roi.subj03.dists.V2d.npy
# True
# True
# 0.31598118807440595
# /media/Working/stan-thesis/projects/distances/subj03/lh.best_roi.subj03.dists.V3v.npy
# True
# True
# 0.2935389845569898
# /media/Working/stan-thesis/projects/distances/subj03/lh.best_roi.subj03.dists.V3d.npy
# True
# True
# 0.16758450599859012
# /media/Working/stan-thesis/projects/distances/subj03/lh.best_roi.subj03.dists.hV4.npy
# True
# True
# 0.2829756664969049
# /media/Working/stan-thesis/projects/distances/subj03/lh.best_roi.subj03.dists.VO-1.npy
# True
# True
# 0.24006494624718466
# /media/Working/stan-thesis/projects/distances/subj03/lh.best_roi.subj03.dists.VO-2.npy
# True
# True
# 0.19758075873291836
# /media/Working/stan-thesis/projects/distances/subj03/lh.best_roi.subj03.dists.PHC-1.npy
# True
# True
# 0.3220444073777802
# /media/Working/stan-thesis/projects/distances/subj03/lh.best_roi.subj03.dists.PHC-2.npy
# True
# True
# 0.22916693228359616
# /media/Working/stan-thesis/projects/distances/subj03/lh.best_roi.subj03.dists.LO-1.npy
# True
# True
# 0.04494123147082143
# /media/Working/stan-thesis/projects/distances/subj03/lh.best_roi.subj03.dists.LO-2.npy
# True
# True
# 0.11519305426225593
# /media/Working/stan-thesis/projects/distances/subj03/lh.best_roi.subj03.dists.TO-1.npy
# True
# True
# 0.14869353162343993
# /media/Working/stan-thesis/projects/distances/subj03/lh.best_roi.subj03.dists.TO-2.npy
# True
# True
# 0.060386669640797204
# /media/Working/stan-thesis/projects/distances/subj03/rh.best_roi.subj03.dists.V1.npy
# True
# True
# 0.29063742837929785
# /media/Working/stan-thesis/projects/distances/subj03/rh.best_roi.subj03.dists.V2v.npy
# True
# True
# 0.37766841936317697
# /media/Working/stan-thesis/projects/distances/subj03/rh.best_roi.subj03.dists.V2d.npy
# True
# True
# 0.304865056525896
# /media/Working/stan-thesis/projects/distances/subj03/rh.best_roi.subj03.dists.V3v.npy
# True
# True
# 0.21549712706189553
# /media/Working/stan-thesis/projects/distances/subj03/rh.best_roi.subj03.dists.V3d.npy
# True
# True
# 0.25245266124535365
# /media/Working/stan-thesis/projects/distances/subj03/rh.best_roi.subj03.dists.hV4.npy
# True
# True
# 0.20684191982889533
# /media/Working/stan-thesis/projects/distances/subj03/rh.best_roi.subj03.dists.VO-1.npy
# True
# True
# 0.36202359562656045
# /media/Working/stan-thesis/projects/distances/subj03/rh.best_roi.subj03.dists.VO-2.npy
# True
# True
# 0.3129846139077503
# /media/Working/stan-thesis/projects/distances/subj03/rh.best_roi.subj03.dists.PHC-1.npy
# True
# True
# 0.3869425135055944
# /media/Working/stan-thesis/projects/distances/subj03/rh.best_roi.subj03.dists.PHC-2.npy
# True
# True
# 0.3660058618064034
# /media/Working/stan-thesis/projects/distances/subj03/rh.best_roi.subj03.dists.LO-1.npy
# True
# True
# 0.14295164295313978
# /media/Working/stan-thesis/projects/distances/subj03/rh.best_roi.subj03.dists.LO-2.npy
# True
# True
# 0.12450609645245009
# /media/Working/stan-thesis/projects/distances/subj03/rh.best_roi.subj03.dists.TO-1.npy
# True
# True
# 0.2603262481930088
# /media/Working/stan-thesis/projects/distances/subj03/rh.best_roi.subj03.dists.TO-2.npy
# True
# True
# 0.009515453934954276
# /media/Working/stan-thesis/projects/distances/subj04/lh.best_roi.subj04.dists.V1.npy
# True
# True
# 0.13834007219924802
# /media/Working/stan-thesis/projects/distances/subj04/lh.best_roi.subj04.dists.V2v.npy
# True
# True
# 0.3674762638717075
# /media/Working/stan-thesis/projects/distances/subj04/lh.best_roi.subj04.dists.V2d.npy
# True
# True
# 0.5531268881692225
# /media/Working/stan-thesis/projects/distances/subj04/lh.best_roi.subj04.dists.V3v.npy
# True
# True
# 0.29819201624403474
# /media/Working/stan-thesis/projects/distances/subj04/lh.best_roi.subj04.dists.V3d.npy
# True
# True
# 0.2791681495357723
# /media/Working/stan-thesis/projects/distances/subj04/lh.best_roi.subj04.dists.hV4.npy
# True
# True
# 0.2378740414261282
# /media/Working/stan-thesis/projects/distances/subj04/lh.best_roi.subj04.dists.VO-1.npy
# True
# True
# 0.16523740202291795
# /media/Working/stan-thesis/projects/distances/subj04/lh.best_roi.subj04.dists.VO-2.npy
# True
# True
# 0.3577216647877655
# /media/Working/stan-thesis/projects/distances/subj04/lh.best_roi.subj04.dists.PHC-1.npy
# True
# True
# 0.4708885568202626
# /media/Working/stan-thesis/projects/distances/subj04/lh.best_roi.subj04.dists.PHC-2.npy
# True
# True
# 0.20931491830254065
# /media/Working/stan-thesis/projects/distances/subj04/lh.best_roi.subj04.dists.LO-1.npy
# True
# True
# 0.1902122975318147
# /media/Working/stan-thesis/projects/distances/subj04/lh.best_roi.subj04.dists.LO-2.npy
# True
# True
# 0.12291457458172898
# /media/Working/stan-thesis/projects/distances/subj04/lh.best_roi.subj04.dists.TO-1.npy
# True
# True
# 0.37397964737929196
# /media/Working/stan-thesis/projects/distances/subj04/lh.best_roi.subj04.dists.TO-2.npy
# True
# True
# 0.36305922340860686
# /media/Working/stan-thesis/projects/distances/subj04/rh.best_roi.subj04.dists.V1.npy
# True
# True
# 0.21606804177858058
# /media/Working/stan-thesis/projects/distances/subj04/rh.best_roi.subj04.dists.V2v.npy
# True
# True
# 0.35028480630234715
# /media/Working/stan-thesis/projects/distances/subj04/rh.best_roi.subj04.dists.V2d.npy
# True
# True
# 0.35276537849997897
# /media/Working/stan-thesis/projects/distances/subj04/rh.best_roi.subj04.dists.V3v.npy
# True
# True
# 0.308469724217719
# /media/Working/stan-thesis/projects/distances/subj04/rh.best_roi.subj04.dists.V3d.npy
# True
# True
# 0.25770274422065487
# /media/Working/stan-thesis/projects/distances/subj04/rh.best_roi.subj04.dists.hV4.npy
# True
# True
# 0.17119763068855973
# /media/Working/stan-thesis/projects/distances/subj04/rh.best_roi.subj04.dists.VO-1.npy
# True
# True
# 0.35497382759371787
# /media/Working/stan-thesis/projects/distances/subj04/rh.best_roi.subj04.dists.VO-2.npy
# True
# True
# 0.47640542359727267
# /media/Working/stan-thesis/projects/distances/subj04/rh.best_roi.subj04.dists.PHC-1.npy
# True
# True
# 0.37516431444758874
# /media/Working/stan-thesis/projects/distances/subj04/rh.best_roi.subj04.dists.PHC-2.npy
# True
# True
# 0.3005326851245218
# /media/Working/stan-thesis/projects/distances/subj04/rh.best_roi.subj04.dists.LO-1.npy
# True
# True
# 0.1417724437535906
# /media/Working/stan-thesis/projects/distances/subj04/rh.best_roi.subj04.dists.LO-2.npy
# True
# True
# 0.1117545949467416
# /media/Working/stan-thesis/projects/distances/subj04/rh.best_roi.subj04.dists.TO-1.npy
# True
# True
# 0.33502708135765713
# /media/Working/stan-thesis/projects/distances/subj04/rh.best_roi.subj04.dists.TO-2.npy
# True
# True
# 0.21804286345077611
# /media/Working/stan-thesis/projects/distances/subj05/lh.best_roi.subj05.dists.V1.npy
# True
# True
# 0.20979470598398375
# /media/Working/stan-thesis/projects/distances/subj05/lh.best_roi.subj05.dists.V2v.npy
# True
# True
# 0.31576140289959576
# /media/Working/stan-thesis/projects/distances/subj05/lh.best_roi.subj05.dists.V2d.npy
# True
# True
# 0.15408424572032495
# /media/Working/stan-thesis/projects/distances/subj05/lh.best_roi.subj05.dists.V3v.npy
# True
# True
# 0.41602400052819033
# /media/Working/stan-thesis/projects/distances/subj05/lh.best_roi.subj05.dists.V3d.npy
# True
# True
# 0.15999804589796643
# /media/Working/stan-thesis/projects/distances/subj05/lh.best_roi.subj05.dists.hV4.npy
# True
# True
# 0.1324289217274015
# /media/Working/stan-thesis/projects/distances/subj05/lh.best_roi.subj05.dists.VO-1.npy
# True
# True
# 0.09834068438042208
# /media/Working/stan-thesis/projects/distances/subj05/lh.best_roi.subj05.dists.VO-2.npy
# True
# True
# 0.15751620567576094
# /media/Working/stan-thesis/projects/distances/subj05/lh.best_roi.subj05.dists.PHC-1.npy
# True
# True
# 0.28292313445280093
# /media/Working/stan-thesis/projects/distances/subj05/lh.best_roi.subj05.dists.PHC-2.npy
# True
# True
# 0.5085927892648924
# /media/Working/stan-thesis/projects/distances/subj05/lh.best_roi.subj05.dists.LO-1.npy
# True
# True
# 0.12042371386622916
# /media/Working/stan-thesis/projects/distances/subj05/lh.best_roi.subj05.dists.LO-2.npy
# True
# True
# 0.08702387677461346
# /media/Working/stan-thesis/projects/distances/subj05/lh.best_roi.subj05.dists.TO-1.npy
# True
# True
# 0.16775662959958093
# /media/Working/stan-thesis/projects/distances/subj05/lh.best_roi.subj05.dists.TO-2.npy
# True
# True
# 0.1722459252187268
# /media/Working/stan-thesis/projects/distances/subj05/rh.best_roi.subj05.dists.V1.npy
# True
# True
# 0.11444957473681049
# /media/Working/stan-thesis/projects/distances/subj05/rh.best_roi.subj05.dists.V2v.npy
# True
# True
# 0.4035781396707254
# /media/Working/stan-thesis/projects/distances/subj05/rh.best_roi.subj05.dists.V2d.npy
# True
# True
# 0.31214346377351004
# /media/Working/stan-thesis/projects/distances/subj05/rh.best_roi.subj05.dists.V3v.npy
# True
# True
# 0.47290036141103
# /media/Working/stan-thesis/projects/distances/subj05/rh.best_roi.subj05.dists.V3d.npy
# True
# True
# 0.4265017915817586
# /media/Working/stan-thesis/projects/distances/subj05/rh.best_roi.subj05.dists.hV4.npy
# True
# True
# 0.052453569142612934
# /media/Working/stan-thesis/projects/distances/subj05/rh.best_roi.subj05.dists.VO-1.npy
# True
# True
# 0.3329100123809232
# /media/Working/stan-thesis/projects/distances/subj05/rh.best_roi.subj05.dists.VO-2.npy
# True
# True
# 0.22043615940645492
# /media/Working/stan-thesis/projects/distances/subj05/rh.best_roi.subj05.dists.PHC-1.npy
# True
# True
# 0.2794218431351001
# /media/Working/stan-thesis/projects/distances/subj05/rh.best_roi.subj05.dists.PHC-2.npy
# True
# True
# 0.18867600504402998
# /media/Working/stan-thesis/projects/distances/subj05/rh.best_roi.subj05.dists.LO-1.npy
# True
# True
# 0.14306538175025665
# /media/Working/stan-thesis/projects/distances/subj05/rh.best_roi.subj05.dists.LO-2.npy
# True
# True
# 0.07783276511463665
# /media/Working/stan-thesis/projects/distances/subj05/rh.best_roi.subj05.dists.TO-1.npy
# True
# True
# 0.28411152673302964
# /media/Working/stan-thesis/projects/distances/subj05/rh.best_roi.subj05.dists.TO-2.npy
# True
# True
# 0.4265562207026062
# /media/Working/stan-thesis/projects/distances/subj06/lh.best_roi.subj06.dists.V1.npy
# True
# True
# 0.2309390407018633
# /media/Working/stan-thesis/projects/distances/subj06/lh.best_roi.subj06.dists.V2v.npy
# True
# True
# 0.2681784925421919
# /media/Working/stan-thesis/projects/distances/subj06/lh.best_roi.subj06.dists.V2d.npy
# True
# True
# 0.29724942945045896
# /media/Working/stan-thesis/projects/distances/subj06/lh.best_roi.subj06.dists.V3v.npy
# True
# True
# 0.15506345697224624
# /media/Working/stan-thesis/projects/distances/subj06/lh.best_roi.subj06.dists.V3d.npy
# True
# True
# 0.1080918126405769
# /media/Working/stan-thesis/projects/distances/subj06/lh.best_roi.subj06.dists.hV4.npy
# True
# True
# 0.08221156854595414
# /media/Working/stan-thesis/projects/distances/subj06/lh.best_roi.subj06.dists.VO-1.npy
# True
# True
# 0.025307746551435174
# /media/Working/stan-thesis/projects/distances/subj06/lh.best_roi.subj06.dists.VO-2.npy
# True
# True
# 0.14208282324548105
# /media/Working/stan-thesis/projects/distances/subj06/lh.best_roi.subj06.dists.PHC-1.npy
# True
# True
# 0.2191728305098675
# /media/Working/stan-thesis/projects/distances/subj06/lh.best_roi.subj06.dists.PHC-2.npy
# True
# True
# 0.19320419138109593
# /media/Working/stan-thesis/projects/distances/subj06/lh.best_roi.subj06.dists.LO-1.npy
# True
# True
# 0.14479247086356517
# /media/Working/stan-thesis/projects/distances/subj06/lh.best_roi.subj06.dists.LO-2.npy
# True
# True
# 0.21464404122515876
# /media/Working/stan-thesis/projects/distances/subj06/lh.best_roi.subj06.dists.TO-1.npy
# True
# True
# 0.172726358065334
# /media/Working/stan-thesis/projects/distances/subj06/lh.best_roi.subj06.dists.TO-2.npy
# True
# True
# 0.04261154056473349
# /media/Working/stan-thesis/projects/distances/subj06/rh.best_roi.subj06.dists.V1.npy
# True
# True
# 0.28613619933153805
# /media/Working/stan-thesis/projects/distances/subj06/rh.best_roi.subj06.dists.V2v.npy
# True
# True
# 0.20762267420137687
# /media/Working/stan-thesis/projects/distances/subj06/rh.best_roi.subj06.dists.V2d.npy
# True
# True
# 0.3370758441393771
# /media/Working/stan-thesis/projects/distances/subj06/rh.best_roi.subj06.dists.V3v.npy
# True
# True
# 0.15287268243986218
# /media/Working/stan-thesis/projects/distances/subj06/rh.best_roi.subj06.dists.V3d.npy
# True
# True
# 0.19981125479249226
# /media/Working/stan-thesis/projects/distances/subj06/rh.best_roi.subj06.dists.hV4.npy
# True
# True
# 0.06508553469225133
# /media/Working/stan-thesis/projects/distances/subj06/rh.best_roi.subj06.dists.VO-1.npy
# True
# True
# 0.06212490646643269
# /media/Working/stan-thesis/projects/distances/subj06/rh.best_roi.subj06.dists.VO-2.npy
# True
# True
# 0.2401475457542338
# /media/Working/stan-thesis/projects/distances/subj06/rh.best_roi.subj06.dists.PHC-1.npy
# True
# True
# 0.19118521159667426
# /media/Working/stan-thesis/projects/distances/subj06/rh.best_roi.subj06.dists.PHC-2.npy
# True
# True
# 0.10797875282872535
# /media/Working/stan-thesis/projects/distances/subj06/rh.best_roi.subj06.dists.LO-1.npy
# True
# True
# 0.136173723021163
# /media/Working/stan-thesis/projects/distances/subj06/rh.best_roi.subj06.dists.LO-2.npy
# True
# True
# 0.1903395033247629
# /media/Working/stan-thesis/projects/distances/subj06/rh.best_roi.subj06.dists.TO-1.npy
# True
# True
# 0.26510305353949565
# /media/Working/stan-thesis/projects/distances/subj06/rh.best_roi.subj06.dists.TO-2.npy
# True
# True
# 0.25171366654660754
# /media/Working/stan-thesis/projects/distances/subj07/lh.best_roi.subj07.dists.V1.npy
# True
# True
# 0.30715913783418736
# /media/Working/stan-thesis/projects/distances/subj07/lh.best_roi.subj07.dists.V2v.npy
# True
# True
# 0.3225527052605437
# /media/Working/stan-thesis/projects/distances/subj07/lh.best_roi.subj07.dists.V2d.npy
# True
# True
# 0.31273089079534194
# /media/Working/stan-thesis/projects/distances/subj07/lh.best_roi.subj07.dists.V3v.npy
# True
# True
# 0.4171723025066571
# /media/Working/stan-thesis/projects/distances/subj07/lh.best_roi.subj07.dists.V3d.npy
# True
# True
# 0.27618696380954094
# /media/Working/stan-thesis/projects/distances/subj07/lh.best_roi.subj07.dists.hV4.npy
# True
# True
# 0.06590635808307843
# /media/Working/stan-thesis/projects/distances/subj07/lh.best_roi.subj07.dists.VO-1.npy
# True
# True
# 0.24919132519959558
# /media/Working/stan-thesis/projects/distances/subj07/lh.best_roi.subj07.dists.VO-2.npy
# True
# True
# 0.2237645955993373
# /media/Working/stan-thesis/projects/distances/subj07/lh.best_roi.subj07.dists.PHC-1.npy
# True
# True
# 0.17371420394797596
# /media/Working/stan-thesis/projects/distances/subj07/lh.best_roi.subj07.dists.PHC-2.npy
# True
# True
# 0.1744809201797078
# /media/Working/stan-thesis/projects/distances/subj07/lh.best_roi.subj07.dists.LO-1.npy
# True
# True
# 0.07830829012889823
# /media/Working/stan-thesis/projects/distances/subj07/lh.best_roi.subj07.dists.LO-2.npy
# True
# True
# 0.08678368191523023
# /media/Working/stan-thesis/projects/distances/subj07/lh.best_roi.subj07.dists.TO-1.npy
# True
# True
# 0.24403670000198105
# /media/Working/stan-thesis/projects/distances/subj07/lh.best_roi.subj07.dists.TO-2.npy
# True
# True
# 0.04029924322280713
# /media/Working/stan-thesis/projects/distances/subj07/rh.best_roi.subj07.dists.V1.npy
# True
# True
# 0.27715378098834115
# /media/Working/stan-thesis/projects/distances/subj07/rh.best_roi.subj07.dists.V2v.npy
# True
# True
# 0.30614068844808134
# /media/Working/stan-thesis/projects/distances/subj07/rh.best_roi.subj07.dists.V2d.npy
# True
# True
# 0.2878188332979247
# /media/Working/stan-thesis/projects/distances/subj07/rh.best_roi.subj07.dists.V3v.npy
# True
# True
# 0.3750584585891156
# /media/Working/stan-thesis/projects/distances/subj07/rh.best_roi.subj07.dists.V3d.npy
# True
# True
# 0.30468487744639267
# /media/Working/stan-thesis/projects/distances/subj07/rh.best_roi.subj07.dists.hV4.npy
# True
# True
# 0.06695688741023312
# /media/Working/stan-thesis/projects/distances/subj07/rh.best_roi.subj07.dists.VO-1.npy
# True
# True
# 0.33643168731347567
# /media/Working/stan-thesis/projects/distances/subj07/rh.best_roi.subj07.dists.VO-2.npy
# True
# True
# 0.08784078350125026
# /media/Working/stan-thesis/projects/distances/subj07/rh.best_roi.subj07.dists.PHC-1.npy
# True
# True
# 0.1404561092673669
# /media/Working/stan-thesis/projects/distances/subj07/rh.best_roi.subj07.dists.PHC-2.npy
# True
# True
# 0.35252612450078424
# /media/Working/stan-thesis/projects/distances/subj07/rh.best_roi.subj07.dists.LO-1.npy
# True
# True
# 0.010654813620635067
# /media/Working/stan-thesis/projects/distances/subj07/rh.best_roi.subj07.dists.LO-2.npy
# True
# True
# 0.02700101396270325
# /media/Working/stan-thesis/projects/distances/subj07/rh.best_roi.subj07.dists.TO-1.npy
# True
# True
# 0.1341962364497237
# /media/Working/stan-thesis/projects/distances/subj07/rh.best_roi.subj07.dists.TO-2.npy
# True
# True
# 0.029736554123044715
# /media/Working/stan-thesis/projects/distances/subj08/lh.best_roi.subj08.dists.V1.npy
# True
# True
# 0.08166759884623495
# /media/Working/stan-thesis/projects/distances/subj08/lh.best_roi.subj08.dists.V2v.npy
# True
# True
# 0.4133679289051331
# /media/Working/stan-thesis/projects/distances/subj08/lh.best_roi.subj08.dists.V2d.npy
# True
# True
# 0.34014044717705744
# /media/Working/stan-thesis/projects/distances/subj08/lh.best_roi.subj08.dists.V3v.npy
# True
# True
# 0.4430175377383421
# /media/Working/stan-thesis/projects/distances/subj08/lh.best_roi.subj08.dists.V3d.npy
# True
# True
# 0.290657786946264
# /media/Working/stan-thesis/projects/distances/subj08/lh.best_roi.subj08.dists.hV4.npy
# True
# True
# 0.2681836652019241
# /media/Working/stan-thesis/projects/distances/subj08/lh.best_roi.subj08.dists.VO-1.npy
# True
# True
# 0.12600571705471864
# /media/Working/stan-thesis/projects/distances/subj08/lh.best_roi.subj08.dists.VO-2.npy
# True
# True
# 0.29550026454130535
# /media/Working/stan-thesis/projects/distances/subj08/lh.best_roi.subj08.dists.PHC-1.npy
# True
# True
# 0.2911454255483469
# /media/Working/stan-thesis/projects/distances/subj08/lh.best_roi.subj08.dists.PHC-2.npy
# True
# True
# 0.5099188438605472
# /media/Working/stan-thesis/projects/distances/subj08/lh.best_roi.subj08.dists.LO-1.npy
# True
# True
# 0.13350839140791956
# /media/Working/stan-thesis/projects/distances/subj08/lh.best_roi.subj08.dists.LO-2.npy
# True
# True
# 0.16297397302847155
# /media/Working/stan-thesis/projects/distances/subj08/lh.best_roi.subj08.dists.TO-1.npy
# True
# True
# 0.12174384650465961
# /media/Working/stan-thesis/projects/distances/subj08/lh.best_roi.subj08.dists.TO-2.npy
# True
# True
# 0.1125342316609785
# /media/Working/stan-thesis/projects/distances/subj08/rh.best_roi.subj08.dists.V1.npy
# True
# True
# 0.0923616921134117
# /media/Working/stan-thesis/projects/distances/subj08/rh.best_roi.subj08.dists.V2v.npy
# True
# True
# 0.21752300945981295
# /media/Working/stan-thesis/projects/distances/subj08/rh.best_roi.subj08.dists.V2d.npy
# True
# True
# 0.23805149392226554
# /media/Working/stan-thesis/projects/distances/subj08/rh.best_roi.subj08.dists.V3v.npy
# True
# True
# 0.05895247368757766
# /media/Working/stan-thesis/projects/distances/subj08/rh.best_roi.subj08.dists.V3d.npy
# True
# True
# 0.14202858147601127
# /media/Working/stan-thesis/projects/distances/subj08/rh.best_roi.subj08.dists.hV4.npy
# True
# True
# 0.2310205456607927
# /media/Working/stan-thesis/projects/distances/subj08/rh.best_roi.subj08.dists.VO-1.npy
# True
# True
# 0.3138590768658795
# /media/Working/stan-thesis/projects/distances/subj08/rh.best_roi.subj08.dists.VO-2.npy
# True
# True
# 0.3016617318698731
# /media/Working/stan-thesis/projects/distances/subj08/rh.best_roi.subj08.dists.PHC-1.npy
# True
# True
# 0.3553015521400384
# /media/Working/stan-thesis/projects/distances/subj08/rh.best_roi.subj08.dists.PHC-2.npy
# True
# True
# 0.3214309460888868
# /media/Working/stan-thesis/projects/distances/subj08/rh.best_roi.subj08.dists.LO-1.npy
# True
# True
# 0.22514653242088475
# /media/Working/stan-thesis/projects/distances/subj08/rh.best_roi.subj08.dists.LO-2.npy
# True
# True
# 0.151138811671305
# /media/Working/stan-thesis/projects/distances/subj08/rh.best_roi.subj08.dists.TO-1.npy
# True
# True
# 0.13161493936998567
# /media/Working/stan-thesis/projects/distances/subj08/rh.best_roi.subj08.dists.TO-2.npy
# True
# True
# 0.2241116820134599
#     hemisphere subject    roi         df  spearmanr         pvalue
# 0           lh  subj01     V1  6762003.0   0.318772   0.000000e+00
# 1           lh  subj01    V2v  1233235.0   0.458136   0.000000e+00
# 2           lh  subj01    V2d  1308153.0   0.438821   0.000000e+00
# 3           lh  subj01    V3v  1010331.0   0.421067   0.000000e+00
# 4           lh  subj01    V3d   977901.0   0.323002  2.601846e-197
# ..         ...     ...    ...        ...        ...            ...
# 219         rh  subj08  PHC-2   768180.0   0.321431  2.484697e-173
# 220         rh  subj08   LO-1   399171.0   0.225147   7.615153e-61
# 221         rh  subj08   LO-2   624403.0   0.151139   1.370520e-34
# 222         rh  subj08   TO-1   191890.0   0.131615   2.027069e-15
# 223         rh  subj08   TO-2   261003.0   0.224112   4.357720e-49
#
# [224 rows x 6 columns]

# %%
distances = np.load(distances_file, allow_pickle=True)
distances
# Out:
# array([['lh', 'subj01', 'V1', 6762003.0, 0.31786482415393413, 0.0],
#        ['lh', 'subj01', 'V2v', 1233235.0, 0.4470616562083212, 0.0],
#        ['lh', 'subj01', 'V2d', 1308153.0, 0.46353960301620484, 0.0],
#        ...,
#        ['rh', 'subj08', 'LO-2', 624403.0, 0.06543641267183707,
#         1.2503162909233462e-07],
#        ['rh', 'subj08', 'TO-1', 191890.0, 0.04113993674275202,
#         0.01343547686177302],
#        ['rh', 'subj08', 'TO-2', 261003.0, 0.11020003871695687,
#         7.453311406216656e-13]], dtype=object)

# %%
distances
# Out:
# array([['lh', 'subj01', 'V1', 6762003.0, 0.31786482415393413, 0.0],
#        ['lh', 'subj01', 'V2v', 1233235.0, 0.4470616562083212, 0.0],
#        ['lh', 'subj01', 'V2d', 1308153.0, 0.46353960301620484, 0.0],
#        ...,
#        ['rh', 'subj08', 'LO-2', 624403.0, 0.06543641267183707,
#         1.2503162909233462e-07],
#        ['rh', 'subj08', 'TO-1', 191890.0, 0.04113993674275202,
#         0.01343547686177302],
#        ['rh', 'subj08', 'TO-2', 261003.0, 0.11020003871695687,
#         7.453311406216656e-13]], dtype=object)

# %%
distances = pd.DataFrame(distances, columns=columns)
distances = distances.astype({c: t for c,t in zip(columns, types)})
distances
# Out:
#     hemisphere subject    roi       df  spearmanr         pvalue
# 0           lh  subj01     V1  6762003   0.318772   0.000000e+00
# 1           lh  subj01    V2v  1233235   0.458136   0.000000e+00
# 2           lh  subj01    V2d  1308153   0.438821   0.000000e+00
# 3           lh  subj01    V3v  1010331   0.421067   0.000000e+00
# 4           lh  subj01    V3d   977901   0.323002  2.601846e-197
# ..         ...     ...    ...      ...        ...            ...
# 219         rh  subj08  PHC-2   768180   0.321431  2.484697e-173
# 220         rh  subj08   LO-1   399171   0.225147   7.615153e-61
# 221         rh  subj08   LO-2   624403   0.151139   1.370520e-34
# 222         rh  subj08   TO-1   191890   0.131615   2.027069e-15
# 223         rh  subj08   TO-2   261003   0.224112   4.357720e-49
#
# [224 rows x 6 columns]

# %%
distances.pvalue[distances.pvalue > 0.05]
# Out:
# 83     0.263060
# 164    0.130104
# 165    0.643263
# 167    0.133916
# Name: pvalue, dtype: float64

# %%
163/167 * 100
# Out:
# 97.60479041916167

# %%
#lh_df = distances[distances['hemisphere'] == 'lh']
#rh_df = distances[distances['hemisphere'] == 'rh']
#lh_df_pivot = lh_df.pivot(index='subject', columns='roi', values='spearmanr')
#rh_df_pivot = rh_df.pivot(index='subject', columns='roi', values='spearmanr')
#lh_df_pivot.to_csv('lh_spearman_rho.csv', index=True)
#rh_df_pivot.to_csv('rh_spearman_rho.csv', index=True)

# %%
for hemi in hemis:
    f = plt.figure()
    df = distances.loc[distances.hemisphere == hemi][["subject", "roi", "spearmanr"]]
    df = df.pivot_table(values='spearmanr', columns='subject', index='roi')
    df = df.reindex(list(rois_corr.keys()))
    plt.matshow(df, fignum =  f.number)
    plt.xticks(range(len(df.columns)), df.columns, fontsize=11, rotation=45)
    plt.yticks(range(len(df.index)), df.index, fontsize=11)
    cb = plt.colorbar()
    cb.ax.tick_params()
    plt.title(f'Correlation Matrix for hemisphere {hemi}', fontsize=14);
    
    correlations = df.to_numpy().flatten()
    correlations_normalized = correlations - correlations.mean()
    correlations_normalized = correlations / correlations.std()
    ks_res = sc.stats.kstest(correlations_normalized, sc.stats.norm.cdf)
    print(f'\tkstest: {ks_res}')
    notnormal = ks_res.pvalue < significance
    if notnormal:
        print('\t\tcorrelations do not follow a normal distribution')
        # do wilcox signed rank test
        res = sc.stats.wilcoxon(
            correlations, 
            y = None,
            zero_method = 'zsplit', 
            nan_policy = 'raise',
            correction = True,
            method = 'approx',
            alternative = 'greater'
        )
        print(f'\t\t\twilcoxon: {res }')
    else:
        print('\t\tcorrelations follow a normal distribution')
        res = sc.stats.ttest_1samp(correlations, popmean=0, alternative = 'greater')
        # should adjust with upscaling factor
        print(f'\t\t\tttest: {res}')
    if res.pvalue < significance:
        print('Sample mean is significantly greater than 0')
    else:
        print('Sample mean is NOT significantly greater than 0')
    plt.show();
# Out:
# 	kstest: KstestResult(statistic=0.7035977723888427, pvalue=3.2568655615175914e-56, statistic_location=0.9486385935225439, statistic_sign=-1)
# 		correlations do not follow a normal distribution
# 			wilcoxon: WilcoxonResult(statistic=6328.0, pvalue=2.0759894279703525e-20)
# Sample mean is significantly greater than 0
# 	kstest: KstestResult(statistic=0.7029957724030231, pvalue=4.237595336525564e-56, statistic_location=1.182857574627722, statistic_sign=-1)
# 		correlations do not follow a normal distribution
# 			wilcoxon: WilcoxonResult(statistic=6328.0, pvalue=2.0759894279703525e-20)
# Sample mean is significantly greater than 0
